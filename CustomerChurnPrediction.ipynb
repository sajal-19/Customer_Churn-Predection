# %%
#import Python Libraries
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.ticker as mtick  
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Telecom Dataset for Analysis

# %%
telecom_data=pd.read_csv("telecom_churn_data.csv")

# %% [markdown]
# Visualizing the Dataset and its Attributes

# %%
telecom_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#total records(cols and rows)
telecom_data.shape
# Out:
# (7043, 21)

# %%
# All Attributes of dataset (column names)
telecom_data.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
# Checking Data types of all Attributes (columns)
telecom_data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Statistical Analysis of all numerical attributes
telecom_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# SeniorCitizen is actually a categorical hence the 25%-50%-75% distribution is not propoer
#
# 75% customers have tenure less than 55 months
#
# Average Monthly charges are USD 64.76 whereas 25% customers pay more than USD 89.85 per month

# %% [markdown]
# ### Plotting Graph Between (Churn(Yes) vs Non-Churn(No)) for the given Dataset

# %%
telecom_data['Churn'].value_counts().plot(kind='bar', figsize=(8, 6))
plt.xlabel("Target Variable(Churn)", labelpad=14)
plt.ylabel("Count of Customer", labelpad=14)
plt.title("Count of TARGET Variable(Churn) per category", y=1.02);

# %%
100*telecom_data['Churn'].value_counts()/len(telecom_data['Churn'])
# Out:
# No     73.463013
# Yes    26.536987
# Name: Churn, dtype: float64

# %%
# total Churn(Yes) and non-Churn(No) Customer
telecom_data['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [markdown]
# Data is highly imbalanced, ratio = 73:27
#
# So we analyse the data with other features while taking the target values separately to get some insights.

# %% [markdown]
# ### Consise Summary Of Data set

# %%
telecom_data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Missing Data Initial Intution

# %%
# Missing Values check in the dataset
missing = pd.DataFrame((telecom_data.isnull().sum())*100/telecom_data.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index',y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %% [markdown]
# ## Data Cleaning

# %%
telecom=telecom_data.copy()

# %%
# Coverting TotalCharges to Numeric DataType
telecom.TotalCharges = pd.to_numeric(telecom.TotalCharges, errors='coerce')
telecom.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %% [markdown]
# 11 Missing Values in TotalCharges

# %%
#Show records having Missing Values
telecom.loc[telecom['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# #### Removing Missing Values

# %%
telecom.dropna(how = 'any', inplace = True)

# %%
telecom.loc[telecom['TotalCharges'].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# No Missing Values in the dataset

# %%
#Max tenure in the datset
print(telecom['tenure'].max())
# Out:
# 72

# %%
# Grouping tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]

telecom['tenure_group'] = pd.cut(telecom.tenure, range(1, 80, 12), right=False, labels=labels)

# %%
#Groups of tenure
telecom['tenure_group'].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %%
#Removing columns that are not required now
telecom.drop(columns= ['customerID','tenure'], axis=1, inplace=True)

# %%
#data after removing columns
telecom.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Univariate Analysis using ploting

# %%
#  Plot distibution of individual predictors by churn
for i, predictor in enumerate(telecom.drop(columns=['Churn', 'TotalCharges', 'MonthlyCharges'])):
    plt.figure(i)
    sns.countplot(data=telecom, x=predictor, hue='Churn')

# %%
# Covert the target value 'Churn' in Binary Numeric Value yes(1),No(0)
telecom['Churn'] = np.where(telecom.Churn == 'Yes',1,0)

# %%
# data
telecom.head()
# Out:
#    gender  SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0  Female              0     Yes         No           No  No phone service
# 1    Male              0      No         No          Yes                No
# 2    Male              0      No         No          Yes                No
# 3    Male              0      No         No           No  No phone service
# 4  Female              0      No         No          Yes                No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No          No
# 1             DSL            Yes           No              Yes          No
# 2             DSL            Yes          Yes               No          No
# 3             DSL            Yes           No              Yes         Yes
# 4     Fiber optic             No           No               No          No
#
# ...

# %%
# Converting all categorical variables to dummy variables
telecom_dummies = pd.get_dummies(telecom)
telecom_dummies.head()
# Out:
#    SeniorCitizen  MonthlyCharges  TotalCharges  Churn  gender_Female  \
# 0              0           29.85         29.85      0              1
# 1              0           56.95       1889.50      0              0
# 2              0           53.85        108.15      1              0
# 3              0           42.30       1840.75      0              0
# 4              0           70.70        151.65      1              1
#
#    gender_Male  Partner_No  Partner_Yes  Dependents_No  Dependents_Yes  ...  \
# 0            0           0            1              1               0  ...
# 1            1           1            0              1               0  ...
# 2            1           1            0              1               0  ...
# 3            1           1            0              1               0  ...
# 4            0           1            0              1               0  ...
#
#    PaymentMethod_Bank transfer (automatic)  \
# 0                                        0
# ...

# %% [markdown]
# Showing Relationship Between MonthlyCharges and TotalCharges using Ploting

# %%
sns.lmplot(data=telecom_dummies, x='MonthlyCharges', y='TotalCharges', fit_reg=False)

# %% [markdown]
# Result: TotalCharges increases as MonthyCharges increases

# %% [markdown]
# #### Churning by MonthlyCharges and TotalCharges

# %%
# Churning By Monthly Charges
Mth = sns.kdeplot(telecom_dummies.MonthlyCharges[(telecom_dummies["Churn"] == 0) ],color="Red", shade=True)
Mth = sns.kdeplot(telecom_dummies.MonthlyCharges[(telecom_dummies["Churn"] == 1) ],ax =Mth, color="Blue", shade=True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('Monthly Charges')
Mth.set_title('Monthly charges by churn')
# Out:
# C:\Users\sajal gupta\AppData\Local\Temp\ipykernel_13908\1786644206.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(telecom_dummies.MonthlyCharges[(telecom_dummies["Churn"] == 0) ],color="Red", shade=True)
# C:\Users\sajal gupta\AppData\Local\Temp\ipykernel_13908\1786644206.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Mth = sns.kdeplot(telecom_dummies.MonthlyCharges[(telecom_dummies["Churn"] == 1) ],ax =Mth, color="Blue", shade=True)
# Text(0.5, 1.0, 'Monthly charges by churn')

# %% [markdown]
# From Graph We can analyze churn is high when monthly charges are high

# %%
# Churn By Total Charges
Tot = sns.kdeplot(telecom_dummies.TotalCharges[(telecom_dummies["Churn"] == 0) ],
                color="Red", shade = True)
Tot = sns.kdeplot(telecom_dummies.TotalCharges[(telecom_dummies["Churn"] == 1) ],
                ax =Tot, color="Blue", shade= True)
Tot.legend(["No Churn","Churn"],loc='upper right')
Tot.set_ylabel('Density')
Tot.set_xlabel('Total Charges')
Tot.set_title('Total charges by churn')
# Out:
# C:\Users\sajal gupta\AppData\Local\Temp\ipykernel_13908\2345186699.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot = sns.kdeplot(telecom_dummies.TotalCharges[(telecom_dummies["Churn"] == 0) ],
# C:\Users\sajal gupta\AppData\Local\Temp\ipykernel_13908\2345186699.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   Tot = sns.kdeplot(telecom_dummies.TotalCharges[(telecom_dummies["Churn"] == 1) ],
# Text(0.5, 1.0, 'Total charges by churn')

# %% [markdown]
# Insight: Higher Churn at Lower Total Charges
#
# Result: Higher Monthly Charges,lower tenure,lower total charges resulting to high churn

# %% [markdown]
# #### Building Corelation with all predictors with 'Churn'

# %%
plt.figure(figsize=(20,8))
telecom_dummies.corr()['Churn'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# Insights from the graph:
# 1. Month to Contract_Month-to-Month,No OnlineSecurity_No,No TechSupport,Tenure Group(1-12),Fibre Optic internet result to
#    high 'Churn'
# 2. Long term Contract,Subscription without internet service,customers engaged for 5+ years result to lower Churn
#
# 3. Gender ,PhoneService has no impact on Churn

# %%
# Visualize with Heatmap
plt.figure(figsize=(12,12))
sns.heatmap(telecom_dummies.corr(), cmap="Paired")
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### Bivariate Analysis using Ploting

# %%
new_df1_target0=telecom.loc[telecom["Churn"]==0]
new_df1_target1=telecom.loc[telecom["Churn"]==1]

# %%
def uniplot(df,col,title,hue =None):
    
    sns.set_style('whitegrid')
    sns.set_context('talk')
    plt.rcParams["axes.labelsize"] = 20
    plt.rcParams['axes.titlesize'] = 22
    plt.rcParams['axes.titlepad'] = 30
    
    
    temp = pd.Series(data = hue)
    fig, ax = plt.subplots()
    width = len(df[col].unique()) + 7 + 4*len(temp.unique())
    fig.set_size_inches(width , 8)
    plt.xticks(rotation=45)
    plt.yscale('log')
    plt.title(title)
    ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue,palette='bright') 
        
    plt.show()

# %%
uniplot(new_df1_target1,col='Partner',title='Distribution of Gender for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target0,col='Partner',title='Distribution of Gender for Non Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='PaymentMethod',title='Distribution of PaymentMethod for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='Contract',title='Distribution of Contract for Churned Customers',hue='gender')

# %%
uniplot(new_df1_target1,col='TechSupport',title='Distribution of TechSupport for Churned Customers',hue='gender')
